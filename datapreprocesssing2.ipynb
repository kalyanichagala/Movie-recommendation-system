# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %cd "C:\Users\srava\Downloads"
# Out:
# C:\Users\srava\Downloads

# %%
moviedata2=pd.read_csv("moviedata2.csv")
# Out:
# C:\Users\srava\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#pd.set_option("display.max_columns",None)

# %%
moviedata2.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
import datetime

# %%
moviedata2["release_date"]=pd.to_datetime(moviedata2["release_date"],errors="coerce")

# %%
moviedata2["release_date"].head()
# Out:
# 0   1995-10-30
# 1   1995-12-15
# 2   1995-12-22
# 3   1995-12-22
# 4   1995-02-10
# Name: release_date, dtype: datetime64[ns]

# %%
moviedata2["release_date"]=moviedata2["release_date"].dt.year

# %%
moviedata2.release_date.value_counts(dropna=False)
# Out:
# 2014.0    1974
# 2015.0    1905
# 2013.0    1889
# 2012.0    1722
# 2011.0    1667
#           ...
# 2020.0       1
# 1887.0       1
# 1878.0       1
# 1874.0       1
# 1883.0       1
# Name: release_date, Length: 136, dtype: int64

# %%
movie17=moviedata2[moviedata2["release_date"]==2017.0]

# %%
movie17.head()
# Out:
#        adult                              belongs_to_collection     budget  \
# 26560  False  {'id': 295, 'name': 'Pirates of the Caribbean ...  230000000
# 26561  False  {'id': 468551, 'name': 'Justice League Collect...          0
# 26565  False  {'id': 131296, 'name': 'Thor Collection', 'pos...          0
# 26566  False  {'id': 284433, 'name': 'Guardians of the Galax...  200000000
# 30536  False                                                NaN          0
#
#                                                   genres  \
# 26560  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 26561  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 26565  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 26566  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 30536  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
#
#                                                 homepage      id    imdb_id  \
# 26560  http://pirates.disney.com/pirates-of-the-carib...  166426  tt1790809
# ...

# %%
movie17["id"].dtypes
# Out:
# dtype('O')

# %%
movierecommend=movie17[["title","genres"]]

# %%
credits=pd.read_csv("creditsmovie.csv")

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %%
#pd.set_option("display.max_colwidth",None)

# %%
#pd.set_option("display.max_columns",100)

# %%
import ast

# %%
credits["id"].dtypes
# Out:
# dtype('int64')

# %%
credits["crew"]=credits["crew"].apply(lambda x : ast.literal_eval(x))
credits["cast"]=credits["cast"].apply(lambda x : ast.literal_eval(x))
movie17["id"]=movie17["id"].apply(lambda x : ast.literal_eval(x))
# Out:
# C:\Users\srava\AppData\Local\Temp/ipykernel_3860/2951307673.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie17["id"]=movie17["id"].apply(lambda x : ast.literal_eval(x))

# %%
final=pd.merge(credits,movie17,on="id",how="inner")

# %%
pd.set_option("display.max_columns",None)

# %%
final.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 1, 'character': 'Captain Jack Spa...
# 1  [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 2  [{'cast_id': 0, 'character': 'Thor Odinson', '...
# 3  [{'cast_id': 3, 'character': 'Peter Quill / St...
# 4  [{'cast_id': 0, 'character': 'King Louis XIV',...
#
#                                                 crew      id  adult  \
# 0  [{'credit_id': '52fe4c9cc3a36847f8236a65', 'de...  166426  False
# 1  [{'credit_id': '55ef66dbc3a3686f1700a52d', 'de...  141052  False
# 2  [{'credit_id': '56a93fa4c3a36872db001e7a', 'de...  284053  False
# 3  [{'credit_id': '59171547925141583c0315a6', 'de...  283995  False
# 4  [{'credit_id': '5431de49c3a36825d300007e', 'de...  245842  False
#
#                                belongs_to_collection     budget  \
# 0  {'id': 295, 'name': 'Pirates of the Caribbean ...  230000000
# 1  {'id': 468551, 'name': 'Justice League Collect...          0
# ...

# %%
final.crew.isnull().sum()
# Out:
# 0

# %%
final.shape
# Out:
# (531, 26)

# %%
final1=final[["cast","crew","id","genres","release_date","title"]]

# %%
director=[]
for x in final["crew"]:
    #print(x)
    mix=[]
    for f in x:
        for h in f:
            #print(h)
            if f[h] == "Director":
                #print(h)
                #print(f["name"])
                mix.append(f["name"])
    director.append(mix)

# %%
director
# Out:
# [['Joachim Rønning', 'Espen Sandberg'],
#  ['Zack Snyder'],
#  ['Taika Waititi'],
#  ['James Gunn'],
#  ['Sean McNamara'],
#  ['Adam Spinks'],
#  ['Rucha Humnabadkar'],
#  ['Sarik Andreasyan'],
#  ['Peter Hutchings'],
#  ['Patty Jenkins'],
#  ['Kevin Munroe'],
#  ['James Ponsoldt'],
#  ['Trish Sie'],
#  [],
#  ['Sean Byrne'],
#  ['Roberto Doveris'],
#  ['Lloyd Kaufman'],
#  ['David Jackson'],
#  ['Demetri Martin'],
#  ['Alexandre Bustillo', 'Julien Maury'],
#  ['Johannes Roberts'],
#  ['Gabe Klinger'],
#  ['Aaron Leong'],
#  ['Olivia Neergaard-Holm', 'Jon Nguyen', 'Rick Barnes'],
#  ['Terry George'],
#  ['Benny Boom'],
#  ['Nacho Vigalondo'],
#  ['Terrence Malick'],
#  ['Derrick Borte'],
#  ['Martin Koolhoven'],
#  ['Alex Helfrecht', 'Jörg Tittel'],
#  ['Laura Poitras'],
#  ['Sara Jordenö'],
#  ["Eddie O'Keefe"],
#  ['Ralitza Petrova'],
#  ['Peter Chelsom'],
#  ['Sonia Kennebeck'],
#  ['Raoul Peck'],
#  ['Ceyda Torun'],
#  ['Lasse Hallström'],
#  ['Julian Rosefeldt'],
# ...

# %%
len(director)
# Out:
# 531

# %%
credits["crew"][0]
# Out:
# [{'credit_id': '52fe4284c3a36847f8024f49',
#   'department': 'Directing',
#   'gender': 2,
#   'id': 7879,
#   'job': 'Director',
#   'name': 'John Lasseter',
#   'profile_path': '/7EdqiNbr4FRjIhKHyPPdFfEEEFG.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f4f',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12891,
#   'job': 'Screenplay',
#   'name': 'Joss Whedon',
#   'profile_path': '/dTiVsuaTVTeGmvkhcyJvKp2A5kr.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f55',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 7,
#   'job': 'Screenplay',
#   'name': 'Andrew Stanton',
#   'profile_path': '/pvQWsu0qc8JFQhMVJkTHuexUAa1.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f5b',
#   'department': 'Writing',
#   'gender': 2,
#   'id': 12892,
#   'job': 'Screenplay',
#   'name': 'Joel Cohen',
#   'profile_path': '/dAubAiZcvKFbboWlj7oXOkZnTSu.jpg'},
#  {'credit_id': '52fe4284c3a36847f8024f61',
#   'department': 'Writing',
#   'gender': 0,
#   'id': 12893,
#   'job': 'Screenplay',
# ...

# %%
final["cast"][0]
# Out:
# [{'cast_id': 1,
#   'character': 'Captain Jack Sparrow',
#   'credit_id': '52fe4c9cc3a36847f8236a53',
#   'gender': 2,
#   'id': 85,
#   'name': 'Johnny Depp',
#   'order': 0,
#   'profile_path': '/kbWValANhZI8rbWZXximXuMN4UN.jpg'},
#  {'cast_id': 9,
#   'character': 'Captain Armando Salazar',
#   'credit_id': '54db4949c3a368122d0017fe',
#   'gender': 2,
#   'id': 3810,
#   'name': 'Javier Bardem',
#   'order': 1,
#   'profile_path': '/grBOK7Ep09JBE3H5LyV5JaZZ1XZ.jpg'},
#  {'cast_id': 16,
#   'character': 'Captain Hector Barbossa',
#   'credit_id': '54e44e5ec3a368454b00a02f',
#   'gender': 2,
#   'id': 118,
#   'name': 'Geoffrey Rush',
#   'order': 2,
#   'profile_path': '/5h91WHSK80YtqTk1bMiar2IZzO2.jpg'},
#  {'cast_id': 7,
#   'character': 'Henry Turner',
#   'credit_id': '54db49359251415a0d0012a0',
#   'gender': 2,
#   'id': 1017347,
#   'name': 'Brenton Thwaites',
#   'order': 3,
#   'profile_path': '/dM0m0OxREfW4HxwV2qQeitS8dfO.jpg'},
#  {'cast_id': 8,
# ...

# %%
actorname1=[]
for x in final["cast"]:
    if x == []:
        y=np.nan
    else:
        y=x[0]["name"]
    #print(x)
    #print(x)
    #print(x[0])
    #print(y)
    actorname1.append(y)

# %%
actorname1
# Out:
# ['Johnny Depp',
#  'Ben Affleck',
#  'Chris Hemsworth',
#  'Chris Pratt',
#  'Pierce Brosnan',
#  'Ben Loyd-Holmes',
#  'Ali Fazal',
#  'Anton Pampushnyy',
#  'Victoria Justice',
#  'Gal Gadot',
#  'Chris Murphy',
#  'Emma Watson',
#  'Anna Kendrick',
#  'Donnie Yen',
#  'Ethan Embry',
#  'Violeta Castillo',
#  'Asta Paredes',
#  'Amanda Leighton',
#  'Demetri Martin',
#  'Stephen Dorff',
#  'Claire Holt',
#  'Lucie Lucas',
#  "Sean O'Donnell",
#  'David Lynch',
#  'Oscar Isaac',
#  'Demetrius Shipp Jr.',
#  'Anne Hathaway',
#  'Cate Blanchett',
#  'Jonathan Rhys Meyers',
#  'Guy Pearce',
#  'Agyness Deyn',
#  'Julian Assange',
#  nan,
#  'Emily Browning',
#  'Irena Ivanova',
#  'Asa Butterfield',
#  'Jesselyn Radack',
#  'Samuel L. Jackson',
#  'Bülent Üstün',
#  'Dennis Quaid',
#  'Cate Blanchett',
#  'Alison Brie',
#  'Charlie Day',
#  'Jamie Foxx',
#  'Dane DeHaan',
#  'Jakob Oftebro',
#  'Vin Diesel',
#  'Douglas Smith',
#  'Alice Lowe',
#  'Will Arnett',
#  'Lina El Arabi',
# ...

# %%
final["cast"]
# Out:
# 0      [{'cast_id': 1, 'character': 'Captain Jack Spa...
# 1      [{'cast_id': 2, 'character': 'Bruce Wayne / Ba...
# 2      [{'cast_id': 0, 'character': 'Thor Odinson', '...
# 3      [{'cast_id': 3, 'character': 'Peter Quill / St...
# 4      [{'cast_id': 0, 'character': 'King Louis XIV',...
#                              ...
# 526    [{'cast_id': 0, 'character': 'Satu', 'credit_i...
# 527    [{'cast_id': 0, 'character': 'Detective Simmon...
# 528                                                   []
# 529    [{'cast_id': 1, 'character': 'Devki Sabarwal',...
# 530                                                   []
# Name: cast, Length: 531, dtype: object

# %%
actorname2=[]
for h in final["cast"]:
    if len(h)<2:
        y=np.nan
    else:
        y=h[1]["name"]
    actorname2.append(y)

# %%
actorname2
# Out:
# ['Javier Bardem',
#  'Henry Cavill',
#  'Tom Hiddleston',
#  'Zoe Saldana',
#  'William Hurt',
#  'Sarah Mac',
#  'Melanie Chandra',
#  'Sanzhar Madiyev',
#  'Eden Sher',
#  'Chris Pine',
#  'Ian James Corlett',
#  'Tom Hanks',
#  'Rebel Wilson',
#  nan,
#  'Shiri Appleby',
#  'Ingrid Isensee',
#  'Catherine Corcoran',
#  'Samantha Boscarino',
#  'Gillian Jacobs',
#  'Lili Taylor',
#  'Mandy Moore',
#  'Anton Yelchin',
#  'Alexandria DeBerry',
#  nan,
#  'Charlotte Le Bon',
#  'Danai Gurira',
#  'Jason Sudeikis',
#  'Konstantin Khabenskiy',
#  'Daniel Huttlestone',
#  'Dakota Fanning',
#  'Jonathan Pryce',
#  'Sarah Harrison',
#  nan,
#  'Luke Grimes',
#  'Ivan Nalbantov',
#  'Britt Robertson',
#  nan,
#  'James Baldwin',
#  nan,
#  'Britt Robertson',
#  'Erika Bauer',
#  'Dave Franco',
#  'Ice Cube',
#  'Michelle Monaghan',
#  'Jason Isaacs',
#  'Ane Dahl Torp',
#  'Ice Cube',
#  'Lucien Laviscount',
#  'Jo Hartley',
#  'Zach Galifianakis',
#  'Sébastien Houbani',
# ...

# %%
len(actorname2)
# Out:
# 531

# %%
actorname3=[]
for h in final["cast"]:
    if len(h)<3:
        y=np.nan
    else:
        y=h[2]["name"]
    actorname3.append(y)

# %%
len(actorname3)
# Out:
# 531

# %%
actorname3
# Out:
# ['Geoffrey Rush',
#  'Gal Gadot',
#  'Cate Blanchett',
#  'Dave Bautista',
#  'Benjamin Walker',
#  'Neil Newbon',
#  'Omi Vaidya',
#  'Sebastien Sisak',
#  'Ashley Rickards',
#  'Robin Wright',
#  'Matt Olsen',
#  'John Boyega',
#  'Brittany Snow',
#  nan,
#  'Kiara Glasco',
#  'Mauricio Vaca',
#  'Zac Amino',
#  'Hannah Kasulka',
#  'Christine Woods',
#  'Sam Strike',
#  'Chris Johnson',
#  'Paulo Calatré',
#  'Gary Busey',
#  nan,
#  'Christian Bale',
#  'Kat Graham',
#  'Tim Blake Nelson',
#  nan,
#  'Dougray Scott',
#  'Carice van Houten',
#  'Fiona Shaw',
#  'Jacob Appelbaum',
#  nan,
#  'Ron Livingston',
#  'Ventzislav Konstantinov',
#  'Carla Gugino',
#  nan,
#  'Malcolm X',
#  nan,
#  'Josh Gad',
#  'Ruby Bustamante',
#  'Aubrey Plaza',
#  'Tracy Morgan',
#  'Dermot Mulroney',
#  'Mia Goth',
#  'Søren Malling',
#  'Samuel L. Jackson',
#  'Cressida Bonas',
#  'Kate Dickie',
#  'Michael Cera',
#  'Babak Karimi',
#  'Sonu Sood',
#  'Kangana Ranaut',
#  'Marci Miller',
# ...

# %%
final["genres"]=final["genres"].apply(lambda x : ast.literal_eval(x))

# %%
genre=[]
for t in final["genres"]:
    grp=[]
    for l in t :
        #print(l)
        for d in l :
            #print(d)
            if d == "name":
                grp.append(l[d])
    genre.append(grp)

# %%
len(genre)
# Out:
# 531

# %%
genre
# Out:
# [['Adventure', 'Action', 'Fantasy', 'Comedy'],
#  ['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
#  ['Action', 'Adventure', 'Fantasy', 'Science Fiction'],
#  ['Action', 'Adventure', 'Comedy', 'Science Fiction'],
#  ['Fantasy', 'Action', 'Adventure'],
#  ['Thriller', 'Adventure'],
#  ['Drama', 'Comedy'],
#  ['Action', 'Fantasy', 'Science Fiction'],
#  ['Comedy'],
#  ['Action', 'Adventure', 'Fantasy'],
#  ['Animation', 'Adventure', 'Comedy', 'Action', 'Family'],
#  ['Drama', 'Thriller', 'Science Fiction'],
#  ['Comedy'],
#  [],
#  ['Horror'],
#  ['Drama'],
#  ['Comedy', 'Horror'],
#  ['TV Movie', 'Thriller'],
#  ['Comedy'],
#  ['Horror'],
#  ['Drama', 'Thriller', 'Horror', 'Adventure'],
#  ['Romance', 'Drama'],
#  ['Comedy', 'Drama', 'Family', 'Fantasy', 'Romance', 'Science Fiction'],
#  ['Documentary'],
#  ['History', 'Romance', 'Drama'],
#  ['Drama', 'Music'],
#  ['Action', 'Comedy', 'Drama', 'Fantasy', 'Science Fiction'],
#  ['Documentary', 'Drama'],
#  ['Drama', 'Music'],
# ...

# %%
final["genre"]=genre

# %%
#final["genres"]=final["genres"].apply(lambda x : ast.literal_eval(x))

# %%
final["genre"]=final["genre"].apply(lambda x : " ".join(x))

# %%
#final["genres"]=final["genre"].apply(lambda x : " ".join(x))

# %%
final["director_name"]=director

# %%
final["actor_1_name"]=actorname1

# %%
final["actor_2_name"]=actorname2

# %%
final["actor_3_name"]=actorname3

# %%
finalnew2=pd.DataFrame({})

# %%
finalnew2[["director_name","actor_1_name","actor_2_name","actor_3_name","movie_title","genres"]]=final[["director_name","actor_1_name","actor_2_name","actor_3_name","title","genre"]]

# %%
finalnew2
# Out:
#              director_name          actor_1_name    actor_2_name  \
# 0          Joachim Rønning           Johnny Depp   Javier Bardem
# 1              Zack Snyder           Ben Affleck    Henry Cavill
# 2            Taika Waititi       Chris Hemsworth  Tom Hiddleston
# 3               James Gunn           Chris Pratt     Zoe Saldana
# 4            Sean McNamara        Pierce Brosnan    William Hurt
# ..                     ...                   ...             ...
# 526       Hannaleena Hauru        Inka Haapamäki   Rosa Honkonen
# 527  Jonathan A. Rosenbaum  Lou Diamond Phillips   Wallace Shawn
# 528             Beth David         Not Available   Not Available
# 529           Ravi Udyawar        Sridevi Kapoor       Sajal Ali
# 530          Daisy Asquith         Not Available   Not Available
#
#         actor_3_name                                       movie_title  \
# 0      Geoffrey Rush  Pirates of the Caribbean: Dead Men Tell No Tales
# ...

# %%
finalnew2["director_name"]=finalnew2["director_name"].apply(lambda x :x[0] if x!=[] else "Not Available")

# %%
finalnew2["actor_1_name"].fillna("Not Available",inplace=True)

# %%
finalnew2["actor_2_name"].fillna("Not Available",inplace=True)

# %%
finalnew2["actor_3_name"].fillna("Not Available",inplace=True)

# %%
finalnew2.isnull().sum().sort_values()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# movie_title      0
# genres           0
# dtype: int64

# %%
finalnew2.to_csv("finalnew2.csv")
