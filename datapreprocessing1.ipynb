# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %cd "C:\Users\srava\Downloads"
# Out:
# C:\Users\srava\Downloads

# %%
moviedata1=pd.read_csv("moviedata1.csv")

# %%
moviedata1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
pd.set_option("display.max_columns",None)

# %%
moviedata1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
moviedata1.title_year.value_counts(dropna=False).sort_values().plot(kind="barh",figsize=(15,15))
# Out:
# <AxesSubplot:>

# %%
moviedata1.isnull().sum().sort_values(ascending=False)
# Out:
# gross                        884
# budget                       492
# aspect_ratio                 329
# content_rating               303
# plot_keywords                153
# title_year                   108
# director_name                104
# director_facebook_likes      104
# num_critic_for_reviews        50
# actor_3_name                  23
# actor_3_facebook_likes        23
# num_user_for_reviews          21
# color                         19
# duration                      15
# facenumber_in_poster          13
# actor_2_name                  13
# actor_2_facebook_likes        13
# language                      12
# actor_1_name                   7
# actor_1_facebook_likes         7
# country                        5
# cast_total_facebook_likes      0
# num_voted_users                0
# movie_title                    0
# movie_imdb_link                0
# genres                         0
# imdb_score                     0
# movie_facebook_likes           0
# dtype: int64

# %%
movierecommendation=["director_name","genres","actor_1_name","actor_2_name","actor_3_name","movie_title"]

# %%
moviedata1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
moviedata1.director_name.value_counts(dropna=False)
# Out:
# NaN                        104
# Steven Spielberg            26
# Woody Allen                 22
# Martin Scorsese             20
# Clint Eastwood              20
#                           ...
# Tom DiCillo                  1
# Rakeysh Omprakash Mehra      1
# Dave Meyers                  1
# Mary Harron                  1
# Beeban Kidron                1
# Name: director_name, Length: 2399, dtype: int64

# %%
moviedata1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
moviedata1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
moviedata1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
recommendby=moviedata1[["director_name","genres","actor_1_name","actor_2_name","actor_3_name","movie_title"]]

# %%
recommendby.head()
# Out:
#        director_name                           genres     actor_1_name  \
# 0      James Cameron  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1     Gore Verbinski         Action|Adventure|Fantasy      Johnny Depp
# 2         Sam Mendes        Action|Adventure|Thriller  Christoph Waltz
# 3  Christopher Nolan                  Action|Thriller        Tom Hardy
# 4        Doug Walker                      Documentary      Doug Walker
#
#        actor_2_name          actor_3_name  \
# 0  Joel David Moore             Wes Studi
# 1     Orlando Bloom        Jack Davenport
# 2      Rory Kinnear      Stephanie Sigman
# 3    Christian Bale  Joseph Gordon-Levitt
# 4        Rob Walker                   NaN
#
#                                          movie_title
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# ...

# %%
recommendby["genres"].dtypes
# Out:
# dtype('O')

# %%
#recommendby["genres"]=recommendby["genres"].str.split("|")

# %%
#recommendby["genres"]=recommendby["genres"].astype("str")

# %%
recommendby["genres"]=recommendby["genres"].str.replace('|'," ")
# Out:
# <ipython-input-21-30d83f919cc9>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   recommendby["genres"]=recommendby["genres"].str.replace('|'," ")
# <ipython-input-21-30d83f919cc9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recommendby["genres"]=recommendby["genres"].str.replace('|'," ")

# %%
recommendby.head()
# Out:
#        director_name                           genres     actor_1_name  \
# 0      James Cameron  Action Adventure Fantasy Sci-Fi      CCH Pounder
# 1     Gore Verbinski         Action Adventure Fantasy      Johnny Depp
# 2         Sam Mendes        Action Adventure Thriller  Christoph Waltz
# 3  Christopher Nolan                  Action Thriller        Tom Hardy
# 4        Doug Walker                      Documentary      Doug Walker
#
#        actor_2_name          actor_3_name  \
# 0  Joel David Moore             Wes Studi
# 1     Orlando Bloom        Jack Davenport
# 2      Rory Kinnear      Stephanie Sigman
# 3    Christian Bale  Joseph Gordon-Levitt
# 4        Rob Walker                   NaN
#
#                                          movie_title
# 0                                            Avatar
# 1          Pirates of the Caribbean: At World's End
# 2                                           Spectre
# 3                             The Dark Knight Rises
# ...

# %%
recommendby.to_csv("data1.csv")
